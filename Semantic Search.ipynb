# %% [markdown]
# # The Task

# %% [markdown]
# Based on a user query, return an existing question which most closely resembles the user's query

# %%
# import libraries
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_hub as hub
from sklearn import preprocessing

import spacy
from spacy.lang.en import English
import spacy
EN = spacy.load('en_core_web_sm')

from IPython.display import HTML
import logging
logging.getLogger('tensorflow').disabled = True #OPTIONAL - to disable outputs from Tensorflow

# %% [markdown]
# ## Import the Data

# %%
data = pd.read_csv('Preprocessed_data.csv')
data
# Out:
#                                               post_corpus  \
# 0       using match attribute python objects array nt ...
# 1       specifying mysql enum django model go specifyi...
# 2       unicode vs utf8 confusion python django stumbl...
# 3       cleanest fastest server setup django deploy me...
# 4       always including user django template context ...
# 5       generate urls django django template language ...
# 6       project design fs layout large django projects...
# 7       would make comma separated string list strings...
# 8       best django search app building django project...
# 9       ignore case python strings easiest way compare...
# 10      create new app startapp django googled around ...
# 11      caching compiled regex objects python time pyt...
# 12      serving dynamically generated zip archives dja...
# 13      python private methods actually private python...
# 14      create triple join table django using django b...
# 15      use form values unbound form web report uses d...
# 16      split string list string happens tokens want s...
# 17      python fastest algorithm removing duplicates l...
# 18      django fcgid fedora core 9 missing fedora core...
# 19      stripping non printable characters string pyth...
# 20      send head http request python 2 trying get hea...
# 21      change width form elements created modelform d...
# 22      list words dictionary start user input would g...
# 23      python regex vs php regex competition instead ...
# 24      join list string caveat along lines previous q...
# 25      translate regular expression idiom perl python...
# 26      adding new element text substring say followin...
# 27      editing xml dictionary python trying generate ...
# 28      best way store set data python list data follo...
# 29      easy way populate slugfield charfield built wa...
# ...                                                   ...
# 140849  expand possibility put offline post event tryi...
# 140850  slicing 1 none statement mean came across code...
# 140851  django get first choice value tuple index gett...
# 140852  creating dataframe dictionary arbitrary length...
# 140853  another way print multiple list elements list ...
# 140854  multiply every matrix numpy array transpose ev...
# 140855  pythonic way handling python code handling nan...
# 140856  django find pillow though installed django str...
# 140857  setting textinput focus equal true makes texti...
# 140858  display dictionary print statement way print c...
# 140859  pygametransformscale work game surface writing...
# 140860  return multi line dictionary currently refacto...
# 140861  attributeerror file object attribute _ committ...
# 140862  plotting scatterplots dataframe grid matplotli...
# 140863  fix error valueerror follower follower object ...
# 140864  displaying large image next 3 smaller images s...
# 140865  get specific word fron strcontains pandas data...
# 140866  installation tensorflow aarch64 error could fi...
# 140867  need filter data rows data past certain month ...
# 140868  find words containing specific letters trying ...
# 140869  focus lost event dispatcher kivy textinput way...
# 140870  shift maximum value difficult formulate questi...
# 140871  checking two dictionaries key val pairs values...
# 140872  unnest explode multiple list 20 background fix...
# 140873  limit users integer input want user input inte...
# 140874  stop loop index value attempting use loop iter...
# 140875  grab value dictionary contains multiple keys d...
# 140876  python regex pattern always start end noticed ...
# 140877  use pandas filter unique test loop large dataf...
# 140878  way visualize azimuthal average 3d cartesian s...
#
#                                          question_content  \
# 0       using match attribute python objects array nt ...
# 1       specifying mysql enum django model go specifyi...
# 2       unicode vs utf8 confusion python django stumbl...
# 3       cleanest fastest server setup django deploy me...
# 4       always including user django template context ...
# 5       generate urls django django template language ...
# 6       project design fs layout large django projects...
# 7       would make comma separated string list strings...
# 8       best django search app building django project...
# 9       ignore case python strings easiest way compare...
# 10      create new app startapp django googled around ...
# 11      caching compiled regex objects python time pyt...
# 12      serving dynamically generated zip archives dja...
# 13      python private methods actually private python...
# 14      create triple join table django using django b...
# 15      use form values unbound form web report uses d...
# 16                               split string list string
# 17      python fastest algorithm removing duplicates l...
# 18      django fcgid fedora core 9 missing fedora core...
# 19      stripping non printable characters string pyth...
# 20      send head http request python 2 trying get hea...
# 21      change width form elements created modelform d...
# 22      list words dictionary start user input would g...
# 23      python regex vs php regex competition instead ...
# 24      join list string caveat along lines previous q...
# 25      translate regular expression idiom perl python...
# 26      adding new element text substring say followin...
# 27      editing xml dictionary python trying generate ...
# 28      best way store set data python list data follo...
# 29      easy way populate slugfield charfield built wa...
# ...                                                   ...
# 140849  expand possibility put offline post event tryi...
# 140850  slicing 1 none statement mean came across code...
# 140851  django get first choice value tuple index gett...
# 140852  creating dataframe dictionary arbitrary length...
# 140853  another way print multiple list elements list ...
# 140854  multiply every matrix numpy array transpose ev...
# 140855  pythonic way handling python code handling nan...
# 140856  django find pillow though installed django str...
# 140857  setting textinput focus equal true makes texti...
# 140858  display dictionary print statement way print c...
# 140859  pygametransformscale work game surface writing...
# 140860  return multi line dictionary currently refacto...
# 140861  attributeerror file object attribute _ committ...
# 140862  plotting scatterplots dataframe grid matplotli...
# 140863  fix error valueerror follower follower object ...
# 140864  displaying large image next 3 smaller images s...
# 140865  get specific word fron strcontains pandas data...
# 140866  installation tensorflow aarch64 error could fi...
# 140867  need filter data rows data past certain month ...
# 140868  find words containing specific letters trying ...
# 140869  focus lost event dispatcher kivy textinput way...
# 140870  shift maximum value difficult formulate questi...
# 140871  checking two dictionaries key val pairs values...
# 140872         unnest explode multiple list 20 background
# 140873  limit users integer input want user input inte...
# 140874  stop loop index value attempting use loop iter...
# 140875  grab value dictionary contains multiple keys d...
# 140876  python regex pattern always start end noticed ...
# 140877  use pandas filter unique test loop large dataf...
# 140878  way visualize azimuthal average 3d cartesian s...
#
#                                         question_url  \
# 0            https://stackoverflow.com/questions/683
# 1          https://stackoverflow.com/questions/21454
# 2          https://stackoverflow.com/questions/22149
# 3          https://stackoverflow.com/questions/26025
# 4          https://stackoverflow.com/questions/41547
# 5          https://stackoverflow.com/questions/43290
# 6          https://stackoverflow.com/questions/44135
# 7          https://stackoverflow.com/questions/44778
# 8          https://stackoverflow.com/questions/55056
# 9          https://stackoverflow.com/questions/62567
# 10         https://stackoverflow.com/questions/64237
# 11         https://stackoverflow.com/questions/65266
# 12         https://stackoverflow.com/questions/67454
# 13         https://stackoverflow.com/questions/70528
# 14         https://stackoverflow.com/questions/72945
# 15         https://stackoverflow.com/questions/75621
# 16         https://stackoverflow.com/questions/88613
# 17         https://stackoverflow.com/questions/89178
# 18         https://stackoverflow.com/questions/92373
# 19         https://stackoverflow.com/questions/92438
# 20        https://stackoverflow.com/questions/107405
# 21        https://stackoverflow.com/questions/110378
# 22        https://stackoverflow.com/questions/112532
# 23        https://stackoverflow.com/questions/118143
# 24        https://stackoverflow.com/questions/118458
# 25        https://stackoverflow.com/questions/122277
# 26        https://stackoverflow.com/questions/125102
# 27        https://stackoverflow.com/questions/127606
# 28        https://stackoverflow.com/questions/128259
# 29        https://stackoverflow.com/questions/141487
# ...                                              ...
# 140849  https://stackoverflow.com/questions/56405377
# 140850  https://stackoverflow.com/questions/56405849
# 140851  https://stackoverflow.com/questions/56405910
# 140852  https://stackoverflow.com/questions/56406088
# 140853  https://stackoverflow.com/questions/56406527
# 140854  https://stackoverflow.com/questions/56406881
# 140855  https://stackoverflow.com/questions/56407075
# 140856  https://stackoverflow.com/questions/56407216
# 140857  https://stackoverflow.com/questions/56407412
# 140858  https://stackoverflow.com/questions/56407797
# 140859  https://stackoverflow.com/questions/56407891
# 140860  https://stackoverflow.com/questions/56408152
# 140861  https://stackoverflow.com/questions/56408714
# 140862  https://stackoverflow.com/questions/56408988
# 140863  https://stackoverflow.com/questions/56409055
# 140864  https://stackoverflow.com/questions/56409225
# 140865  https://stackoverflow.com/questions/56409663
# 140866  https://stackoverflow.com/questions/56410003
# 140867  https://stackoverflow.com/questions/56410155
# 140868  https://stackoverflow.com/questions/56410399
# 140869  https://stackoverflow.com/questions/56410573
# 140870  https://stackoverflow.com/questions/56410654
# 140871  https://stackoverflow.com/questions/56410679
# 140872  https://stackoverflow.com/questions/56410811
# 140873  https://stackoverflow.com/questions/56411224
# 140874  https://stackoverflow.com/questions/56411403
# 140875  https://stackoverflow.com/questions/56411413
# 140876  https://stackoverflow.com/questions/56411530
# 140877  https://stackoverflow.com/questions/56411591
# 140878  https://stackoverflow.com/questions/56411676
#
#                                                      tags  \
# 0                                 python|arrays|iteration
# 1                 python|mysql|django|django-models|enums
# 2                                   python|django|unicode
# 3                            python|django|apache|hosting
# 4            python|django|authentication|session|cookies
# 5                           python|django|url|django-urls
# 6                                           python|django
# 7                                             python|list
# 8                      python|django|search|search-engine
# 9                          python|string|case-insensitive
# 10                                          python|django
# 11                                   python|regex|caching
# 12                                          python|django
# 13      python|python-2.7|encapsulation|information-hi...
# 14              python|django|model-view-controller|model
# 15                                          python|django
# 16                               python|string|list|split
# 17                                  python|algorithm|list
# 18                    python|django|apache2|fastcgi|fcgid
# 19                            python|string|non-printable
# 20       python|python-2.7|http|http-headers|content-type
# 21       python|html|django|django-forms|django-templates
# 22                                 python|list|dictionary
# 23                                       php|python|regex
# 24                                 python|string|list|csv
# 25                                      python|regex|perl
# 26                 javascript|jquery|python|beautifulsoup
# 27                                  python|xml|dictionary
# 28                  python|dictionary|data-structures|set
# 29                                     python|django|slug
# ...                                                   ...
# 140849       python|django|django-models|django-templates
# 140850                  python|arrays|numpy|numpy-slicing
# 140851       python|django|django-models|django-templates
# 140852                        python|dataframe|dictionary
# 140853                                        python|list
# 140854                                 python|loops|numpy
# 140855                        python-3.x|pandas|dataframe
# 140856  python|django|docker|python-imaging-library|al...
# 140857               python|python-3.x|kivy|kivy-language
# 140858                       python|python-3.x|dictionary
# 140859                      python|python-3.x|pygame|zoom
# 140860                 python|dictionary|return|multiline
# 140861                                      python|django
# 140862             python|matplotlib|seaborn|scatter-plot
# 140863                               python|django|github
# 140864                       python|python-3.x|pyqt|pyqt5
# 140865                                  python-3.x|pandas
# 140866                        python|tensorflow|pip|arm64
# 140867                                      python|pandas
# 140868    python|regex|string|regex-negation|python-regex
# 140869               python|python-3.x|kivy|kivy-language
# 140870                            python|pandas|dataframe
# 140871                                       python|numpy
# 140872                        python-3.x|pandas|dataframe
# 140873                                  python|python-3.x
# 140874                              python|loops|selenium
# 140875                                  python|dictionary
# 140876                          python|regex|python-regex
# 140877                           python|python-3.x|pandas
# 140878                python|arrays|cartesian-coordinates
#
#         overall_scores_norm  sentiment_polarity  sentiment_subjectivity  \
# 0                  0.012227            0.163567                0.568209
# 1                  0.029648            0.035299                0.536159
# 2                  0.007405            0.082857                0.403250
# 3                  0.008494            0.205105                0.483688
# 4                  0.015027            0.052020                0.628824
# 5                  0.006472            0.080000                0.468333
# 6                  0.004916            0.124153                0.470832
# 7                  0.139619           -0.014071                0.537851
# 8                  0.026226            0.181002                0.492883
# 9                  0.013160            0.075911                0.541590
# 10                 0.012849            0.201130                0.437860
# 11                 0.001339            0.128704                0.576876
# 12                 0.017516            0.013797                0.402989
# 13                 0.185971            0.098592                0.495546
# 14                 0.000872           -0.052500                0.377292
# 15                 0.000095            0.066515                0.388939
# 16                 0.021249           -0.156337                0.653670
# 17                 0.017671            0.090934                0.534763
# 18                -0.000683            0.000000                0.500000
# 19                 0.024515            0.195652                0.570736
# 20                 0.050180           -0.004035                0.397661
# 21                 0.018760            0.171875                0.355655
# 22                 0.005539            0.132461                0.478018
# 23                 0.001961            0.156141                0.578046
# 24                 0.000717            0.039394                0.299242
# 25                 0.009894            0.133661                0.507972
# 26                -0.000217            0.284930                0.536869
# 27                 0.005850            0.102444                0.561338
# 28                -0.000217           -0.018955                0.501044
# 29                 0.010361           -0.039847                0.529898
# ...                     ...                 ...                     ...
# 140849            -0.000683           -0.100000                0.500000
# 140850            -0.000683            0.144596                0.391893
# 140851            -0.000372            0.000000                0.133333
# 140852            -0.000683           -0.475000                0.875000
# 140853            -0.000839            0.037963                0.494312
# 140854            -0.000528            0.050000                0.437500
# 140855            -0.000683            0.000000                0.000000
# 140856            -0.000683            0.000000                0.500000
# 140857            -0.000683            0.000000                0.562500
# 140858            -0.000839            0.107143                0.628571
# 140859            -0.000839           -0.271717                0.474369
# 140860            -0.000372            0.049167                0.350000
# 140861            -0.000839            0.000000                0.000000
# 140862            -0.000994            0.166667                0.833333
# 140863            -0.000839            0.078571                0.615476
# 140864            -0.000683            0.000000                0.050000
# 140865            -0.000528            0.184000                0.630000
# 140866            -0.000839            0.351587                0.702381
# 140867            -0.000217           -0.146667                0.563810
# 140868            -0.000372           -0.114955                0.466861
# 140869            -0.000839            0.000000                0.400000
# 140870            -0.000839           -0.562500                0.775000
# 140871            -0.000994           -0.182500                0.740000
# 140872            -0.000839            0.000000                0.000000
# 140873            -0.000372           -0.034615                0.603846
# 140874            -0.000061            0.375000                0.375000
# 140875            -0.000683           -0.155303                0.862879
# 140876            -0.000217            0.246528                0.512500
# 140877            -0.000839            0.700000                0.600000
# 140878            -0.000839            0.166667                0.325000
#
#                                           processed_title  \
# 0              using match attribute python objects array
# 1                      specifying mysql enum django model
# 2                 unicode vs utf8 confusion python django
# 3                    cleanest fastest server setup django
# 4           always including user django template context
# 5                                    generate urls django
# 6          project design fs layout large django projects
# 7          would make comma separated string list strings
# 8                                  best django search app
# 9                              ignore case python strings
# 10                         create new app startapp django
# 11                  caching compiled regex objects python
# 12      serving dynamically generated zip archives django
# 13                python private methods actually private
# 14                        create triple join table django
# 15                           use form values unbound form
# 16                                      split string list
# 17      python fastest algorithm removing duplicates l...
# 18                     django fcgid fedora core 9 missing
# 19       stripping non printable characters string python
# 20                        send head http request python 2
# 21      change width form elements created modelform d...
# 22                 list words dictionary start user input
# 23                              python regex vs php regex
# 24                                join list string caveat
# 25         translate regular expression idiom perl python
# 26                      adding new element text substring
# 27                          editing xml dictionary python
# 28                         best way store set data python
# 29                  easy way populate slugfield charfield
# ...                                                   ...
# 140849          expand possibility put offline post event
# 140850                      slicing 1 none statement mean
# 140851                django get first choice value tuple
# 140852  creating dataframe dictionary arbitrary length...
# 140853  another way print multiple list elements list ...
# 140854  multiply every matrix numpy array transpose ev...
# 140855  pythonic way handling python code handling nan...
# 140856                django find pillow though installed
# 140857  setting textinput focus equal true makes texti...
# 140858                 display dictionary print statement
# 140859             pygametransformscale work game surface
# 140860                       return multi line dictionary
# 140861  attributeerror file object attribute _ committ...
# 140862    plotting scatterplots dataframe grid matplotlib
# 140863  fix error valueerror follower follower object ...
# 140864       displaying large image next 3 smaller images
# 140865                 get specific word fron strcontains
# 140866  installation tensorflow aarch64 error could fi...
# 140867      need filter data rows data past certain month
# 140868             find words containing specific letters
# 140869         focus lost event dispatcher kivy textinput
# 140870                                shift maximum value
# 140871  checking two dictionaries key val pairs values...
# 140872                    unnest explode multiple list 20
# 140873                          limit users integer input
# 140874                              stop loop index value
# 140875       grab value dictionary contains multiple keys
# 140876              python regex pattern always start end
# 140877                 use pandas filter unique test loop
# 140878  way visualize azimuthal average 3d cartesian s...
#
#                                            original_title  overall_scores
# 0       Using 'in' to match an attribute of Python obj...              84
# 1               Specifying a mySQL ENUM in a Django model             196
# 2          Unicode vs UTF-8 confusion in Python / Django?              53
# 3              Cleanest & Fastest server setup for Django              60
# 4       Always including the user in the django templa...             102
# 5                          How to generate urls in django              47
# 6       Project design / FS layout for large django pr...              37
# 7       How would you make a comma-separated string fr...             903
# 8                      What's the best Django search app?             174
# 9                           Ignore case in Python strings              90
# 10      When to create a new app (with startapp) in Dj...              88
# 11              Caching compiled regex objects in Python?              14
# 12      Serving dynamically generated ZIP archives in ...             118
# 13      Why are Python's 'private' methods not actuall...            1201
# 14          How to create a triple-join table with Django              11
# 15            How to use form values from an unbound form               6
# 16                   How do I split a string into a list?             142
# 17      In Python, what is the fastest algorithm for r...             119
# 18      Django + FCGID on Fedora Core 9 -- what am I m...               1
# 19      Stripping non printable characters from a stri...             163
# 20       How do you send a HEAD HTTP request in Python 2?             328
# 21      Change the width of form elements created with...             126
# 22      List all words in a dictionary that start with...              41
# 23                              Python Regex vs PHP Regex              18
# 24          How can I join a list into a string (caveat)?              10
# 25      How do you translate this regular-expression i...              69
# 26                   Adding New Element to Text Substring               4
# 27                 Editing XML as a dictionary in python?              43
# 28      What is the best way to store set data in Python?               4
# 29      Is there an easy way to populate SlugField fro...              72
# ...                                                   ...             ...
# 140849  Expand the possibility to put offline a post a...               1
# 140850  Slicing with :-1 and None - What does each of ...               1
# 140851          Django: Get first Choice Value from tuple               3
# 140852  Creating a dataframe from dictionary with arbi...               1
# 140853  Is there another way to print multiple list el...               0
# 140854  Multiply every matrix of a numpy array with th...               2
# 140855  Pythonic way of handling a python code for han...               1
# 140856       Django does not find Pillow though installed               1
# 140857  Why is it that setting TextInput focus equal t...               1
# 140858              Display dictionary in print statement               0
# 140859  pygame.transform.scale does not work on the "g...               0
# 140860                     Return a multi-line dictionary               3
# 140861  AttributeError: 'file' object has no attribute...               0
# 140862  Plotting scatterplots from a dataframe on a gr...              -1
# 140863  How to fix error "ValueError: <Follower: Follo...               0
# 140864  Displaying a large image next to 3 smaller images               1
# 140865     How to get the specific word fron str.contains               2
# 140866  Installation of Tensorflow on aarch64: Error: ...               0
# 140867  Need to filter data rows where the data is pas...               4
# 140868  How to Find Words Not Containing Specific Lett...               3
# 140869  Is there a focus lost event dispatcher for a k...               0
# 140870                            Shift the maximum value               0
# 140871  Checking if two dictionaries of key-val pairs ...              -1
# 140872                 unnest (explode) multiple list 2.0               0
# 140873                How to limit a users integer input?               3
# 140874                  Stop a For Loop at an Index Value               5
# 140875  How to grab a value from a dictionary which co...               1
# 140876  In Python, should a regex pattern always start...               4
# 140877  How can I use a pandas filter and unique for t...               0
# 140878  Is there a way to visualize an azimuthal avera...               0
#
# [140879 rows x 10 columns]

# %% [markdown]
# ## Import saved WordEmbeddings

# %%
# Import saved Wordvec Embeddings
import gensim
w2v_model = gensim.models.word2vec.Word2Vec.load('models/SO_word2vec_embeddings.bin')

# %% [markdown]
# ## Calculate Sentence Embeddings
# In order to calculate the embeddings for an entire sentence, I defined the following function which averages the the embeddings for each valid token

# %%
def question_to_vec(question, embeddings, dim=300):
    question_embedding = np.zeros(dim)
    valid_words = 0
    for word in question.split(' '):
        if word in embeddings:
            valid_words += 1
            question_embedding += embeddings[word]
    if valid_words > 0:
        return question_embedding/valid_words
    else:
        return question_embedding

# %%
'''
all_title_embeddings = []
for title in data.processed_title:
    all_title_embeddings.append(question_to_vec(title, w2v_model))
all_title_embeddings = np.array(all_title_embeddings)

embeddings = pd.DataFrame(data = all_title_embeddings)
embeddings.to_csv('models/title_embeddings.csv', index=False)
'''
# Out:
# C:\Users\Rohit\Anaconda3\envs\deeplearning\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   """
# C:\Users\Rohit\Anaconda3\envs\deeplearning\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   import sys

# %% [markdown]
# Since the number of titles have have is fixed, I saved the sentence embeddings for all titles in a .csv file to save computation time on future runs

# %%
all_title_embeddings = pd.read_csv('models/title_embeddings.csv').values

# %% [markdown]
# ## Import the saved model

# %%
import keras.backend as K

# Custom loss function to handle multilabel classification task
def multitask_loss(y_true, y_pred):
    # Avoid divide by 0
    y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
    # Multi-task loss
    return K.mean(K.sum(- y_true * K.log(y_pred) - (1 - y_true) * K.log(1 - y_pred), axis=1))
# Out:
# Using TensorFlow backend.

# %%
from keras.models import load_model
import keras.losses

keras.losses.multitask_loss = multitask_loss
model = load_model('models/Tag_predictor.h5')

# %%
def predict_tags(text, include_neutral=True):
    # Tokenize text
    x_test = pad_sequences(tokenizer.texts_to_sequences([text]), maxlen=MAX_SEQUENCE_LENGTH)
    # Predict
    prediction = model.predict([x_test])[0]
    for i,value in enumerate(prediction):
        if value > 0.5:
            prediction[i] = 1
        else:
            prediction[i] = 0
    tags = tag_encoder.inverse_transform(np.array([prediction]))
    return tags

# %%
import re
import nltk
import inflect
from nltk.corpus import stopwords

def tokenize_text(text):
    "Apply tokenization using spacy to docstrings."
    tokens = EN.tokenizer(text)
    return [token.text.lower() for token in tokens if not token.is_space]

def to_lowercase(words):
    """Convert all characters to lowercase from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = word.lower()
        new_words.append(new_word)
    return new_words

def remove_punctuation(words):
    """Remove punctuation from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = re.sub(r'[^\w\s]', '', word)
        if new_word != '':
            new_words.append(new_word)
    return new_words

def remove_stopwords(words):
    """Remove stop words from list of tokenized words"""
    new_words = []
    for word in words:
        if word not in stopwords.words('english'):
            new_words.append(word)
    return new_words

def normalize(words):
    words = to_lowercase(words)
    words = remove_punctuation(words)
    words = remove_stopwords(words)
    return words

def tokenize_code(text):
    "A very basic procedure for tokenizing code strings."
    return RegexpTokenizer(r'\w+').tokenize(text)

def preprocess_text(text):
    return ' '.join(normalize(tokenize_text(text)))

# %% [markdown]
# ## Import the saved Tokenizer

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

MAX_SEQUENCE_LENGTH = 300
import pickle
with open('models/tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

# %% [markdown]
# ## Getting the most similar results
# So the way we actually calculate the the most similar results, is by comparing how far each result is from the query in terms of distance. This can only be done if both the query and the results are in a shared vector space. **Fortunately, that is exactly what our word embeddings are for**. They create each sentence as a vector in the embedding space, which makes it easy for us to distinguish them.
#
# After we have those vectors, we can assign a **Similarity Measure** as a metric which measures the closeness of two vectors. Common examples are Cosine distance, Euclidean distance and more.
#
# **However, for this specific task, I decided to assign a custom similarity measure**. It is defined as follows:
#
# ![Similarity Measure](jupyter_imgs/similaritymeasure.png)
#
# - It considers the cosine distance as a base measure
# - It takes into account the popularity of the post based on the votes it has received by users at StackOverflow
# - It takes into account the overall sentiment of the responses that people have made. A positive sentiment entails that the answers were helpful and thus is a good post

# %%
from IPython.display import HTML
import logging
from sklearn.metrics.pairwise import cosine_similarity

search_string = "Combine lists of lists" 
search_string = ' '.join(normalize(tokenize_text(search_string)))
results_returned = "5" 
search_vect = np.array([question_to_vec(search_string, w2v_model)])    # Vectorize the user query

# Calculate Cosine similarites for the query and all titles
cosine_similarities = pd.Series(cosine_similarity(search_vect, all_title_embeddings)[0])

# Custom Similarity Measure
cosine_similarities = cosine_similarities*(1 + 0.4*data.overall_scores_norm + 0.1*(data.sentiment_polarity))

output =""
for i,j in cosine_similarities.nlargest(int(results_returned)).iteritems():
    output += '<a target="_blank" href='+ str(data.question_url[i])+'><h2>' + data.original_title[i] + '</h2></a>'
    output += '<h3> Similarity Score: ' + str(j) + '</h3>'
    output += '<h3> Stackover Votes: ' + str(data.overall_scores[i]) + '</h3>'
    output +='<p style="font-family:verdana; font-size:110%;"> '
    for i in data.question_content[i][:50].split():
        if i.lower() in search_string:
            output += " <b>"+str(i)+"</b>"
        else:
            output += " "+str(i)
    output += "</p><hr>"
    
output = '<h3>Results:</h3>'+output
display(HTML(output))
# Out:
# C:\Users\Rohit\Anaconda3\envs\deeplearning\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   """
# C:\Users\Rohit\Anaconda3\envs\deeplearning\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   import sys
# <h3>Results:</h3><a target="_blank" href=https://stackoverflow.com/questions/1720421><h2>How do I concatenate two lists in Python?</h2></a><h3> Similarity Score: 0.9988480985354673</h3><h3> Stackover Votes: 4279</h3><p style="font-family:verdana; font-size:110%;">  concatenate two <b>lists</b> python concatenate two <b>lists</b></p><hr><a target="_blank" href=https://stackoverflow.com/questions/26702846><h2>How to Merge Lists of Lists</h2></a><h3> Similarity Score: 0.9472702607038342</h3><h3> Stackover Votes: 8</h3><p style="font-family:verdana; font-size:110%;">  merge <b>lists</b> <b>lists</b> working python coding project <b>st</b></p><hr><a target="_blank" href=https://stackoverflow.com/questions/48170089><h2>Merge 2 lists of lists</h2></a><h3> Similarity Score: 0.9442272692300363</h3><h3> Stackover Votes: 5</h3><p style="font-family:verdana; font-size:110%;">  merge 2 <b>lists</b> <b>lists</b> im looking merge 2 <b>lists</b> <b>lists</b></p><hr><a target="_blank" href=https://stackoverflow.com/questions/24830804><h2>Convert 2 lists into list of lists</h2></a><h3> Similarity Score: 0.9320485322581505</h3><h3> Stackover Votes: 5</h3><p style="font-family:verdana; font-size:110%;">  convert 2 <b>lists</b> <b>list</b> <b>lists</b> 2 <b>lists</b></p><hr><a target="_blank" href=https://stackoverflow.com/questions/6824212><h2>Python: Merging lists with lists</h2></a><h3> Similarity Score: 0.9311796475042384</h3><h3> Stackover Votes: 2</h3><p style="font-family:verdana; font-size:110%;">  python merging <b>lists</b> <b>lists</b> <b>list</b></p><hr>
